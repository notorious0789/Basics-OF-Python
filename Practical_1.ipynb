# %% [markdown]
# <a href="https://colab.research.google.com/github/notorious0789/Basics-OF-Python/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA using python
# ## Experiment - 1
# ### Python Basics

# %%
# First Program
print("I am Learning Python")
# Out:
# I am Learning Python

# %%
print('I am at Symbiosis')
# Out:
# I am at Symbiosis

# %%
#First Python Program/ String
print("Hello, Welcome to Python")
# Out:
# Hello, Welcome to Python

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
# Comments
#This is a Comment
print("Hello World")
# Out:
# Hello World

# %%
# Many Statements
print("Hello World")
print("Have a good day")
print("Learning Python is fun !")
# Out:
# Hello World
# Have a good day
# Learning Python is fun !

# %%
print("Hello"); print("How are you"); print("Bye bye!")
# Out:
# Hello
# How are you
# Bye bye!

# %%
print("Python is fun !") print("Really!")
# Out:
#   File "/tmp/ipython-input-55618608.py", line 1
#     print("Python is fun !") print("Really!")
#                              ^
# SyntaxError: invalid syntax

# %%
print("This will work")
print('This will also work')
# Out:
# This will work
# This will also work

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.

# %%
# Print Numbers
a=3
print(a)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
# Variables
x= 5
y= "Hello World!"

print(x)
print(y)
# Out:
# 5
# Hello World!

# %%
# Case - Sensitive
a= 4
A= "Sally"

print(a)
print(A)
# Out:
# 4
# Sally

# %%
# Many Values to Multiple Variables
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Basic Mathematical Operators

a=10
b=5
print("Addition=", a+b)
print("Subtraction=", a-b)
print("Multiplication=", a*b)
print("Division=", a/b)
# Out:
# Addition= 15
# Subtraction= 5
# Multiplication= 50
# Division= 2.0

# %%
# Understanding Data Types
x = 10
y = 3.14
z = "Python"
flag = True
cmplx = 3+2j

print(type(x))
print(type(y))
print(type(z))
print(type(flag))
print(type(cmplx))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
# Taking Input from the User
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Apoorba
# Hello Apoorba

# %%
# Taking Input from the User - Simple Calculator
a = int(input("Enter your First Number: "))
b = int(input("Enter your Second Number: "))

print("Addition", a+b)
print("Subtraction=", a-b)
print("Multiplication=", a*b)
print("Division=", a/b)
# Out:
# Enter your First Number: 4
# Enter your Second Number: 2
# Addition 6
# Subtraction= 2
# Multiplication= 8
# Division= 2.0

# %%
# Taking Input from the User - MARKS OF FIVE SUBJECTS

S1 = int(input("Enter your First Number: "))
S2 = int(input("Enter your Second Number: "))
S3 = int(input("Enter your Second Number: "))
S4 = int(input("Enter your Second Number: "))
S5 = int(input("Enter your Second Number: "))

TotalMarks = S1+S2+S3+S3+S4+S5

print("Total Marks = ", TotalMarks)
print("Average Marks = ", TotalMarks/5)
# Out:
# Enter your First Number: 98
# Enter your Second Number: 99
# Enter your Second Number: 96
# Enter your Second Number: 95
# Enter your Second Number: 97
# Total Marks =  581
# Average Marks =  116.2

# %%
# Taking Input from the User - AREA OF RECTANGLE

Length = int(input("Enter your Length : "))
Breadth = int(input("Enter your Breadth: "))

Area = Length * Breadth

print("Area of the Rectangle = ", Area)
# Out:
# Enter your Length : 5
# Enter your Breadth: 6
# Area of the Rectangle =  30

# %%
# Taking Input from the User - AREA OF CIRLCE

Radius = int(input("Enter your Length : "))

Area = Radius * Radius * 3.14

print("Area of the Circle = ", Area)
# Out:
# Enter your Length : 5
# Area of the Circle =  78.5

# %%
a = 3**3
b= 3*3
print(a)
print(b)
# Out:
# 27
# 9

# %%
# Tuple Appending

A = (3, 4, 5) + (5, 6, 8)
print(A)
# Out:
# (3, 4, 5, 5, 6, 8)
